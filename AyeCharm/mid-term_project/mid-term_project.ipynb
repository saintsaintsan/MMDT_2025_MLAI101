# %% [markdown]
# <a href="https://colab.research.google.com/github/AyeCharm7/MMDT_2025_MLAI101/blob/AyeCharm/AyeCharm/mid-term_project/mid-term_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Understanding the data**

# %%
import pandas as pd
df=pd.read_csv('/content/Housing.csv')
print(df.columns)
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'parking'], dtype='object')

# %% [markdown]
# Data Splitting

# %%
X =df[['area', 'stories']].values
y=df['price'].values

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,
                                                    test_size = 0.3,
                                                    random_state = 42)

# Print the size of the training and testing data
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
print(len(df))
# Out:
# (350, 2) (350,)
# (151, 2) (151,)
# 501

# %% [markdown]
# **Featuring the scale**

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
X_scaled = scale.fit_transform(X_train)
X_test_scaled = scale.transform(X_test)

# %% [markdown]
# **Visualize the data**

# %%
# Import matplotlib for visualization
import matplotlib.pyplot as plt

plt.plot(y_train, ytrain_pred, 'k*')
plt.plot(y_test, ytest_pred, 'r*')

plt.title("Predicted value vs. Actual value")
plt.legend(["Training data", "Testing data"])
plt.show()

# %% [markdown]
# **Linear Regression Model**

# %%
## linear regression model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

lr = LinearRegression()
lr.fit(X_scaled, y_train)

# predicting y_trained data
# finding mae,mse and r2 for training data
ytrain_pred = lr.predict(X_scaled)
mae = mean_absolute_error(y_train, ytrain_pred)
mse = mean_squared_error(y_train, ytrain_pred)
r2 = r2_score(y_train, ytrain_pred)

print(f"Training Data:")
print(f"Mean Absolute Error: {mae}")
print(f"Mean Squared Error: {mse}")
print(f"R2 Score: {r2}")
# Out:
# Training Data:
# Mean Absolute Error: 918408.8496619147
# Mean Squared Error: 1673224013890.9565
# R2 Score: 0.4114569105882494

# %% [markdown]
# **Testing Model**

# %%
# testing model

# predicting y_test data
# finding mae,mse and r2 for training data
ytest_pred = lr.predict(X_test_scaled)
mae = mean_absolute_error(y_test, ytest_pred)
mse = mean_squared_error(y_test, ytest_pred)
r2 = r2_score(y_test, ytest_pred)
print(f"Testing Data:")
print(f"Mean Absolute Error: {mae}")
print(f"Mean Squared Error: {mse}")
print(f"R2 Score: {r2}")
# Out:
# Testing Data:
# Mean Absolute Error: 1162055.035550395
# Mean Squared Error: 2632570392001.295
# R2 Score: 0.3459551624767614
