# %%
import pandas as pd

df=pd.read_csv('https://raw.githubusercontent.com/saintsaintsan/Supervised-Machine-Learning/refs/heads/main/data/fraud.csv', index_col = 0)
y = df['Class'].values
df = df.iloc[:,1:]
X = df.drop(columns = 'Class').values

df[['Class']].value_counts()
# Out:
# Class
# 0        21337
# 1          356
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,
                                    test_size = 0.40,
                                    random_state=1)

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.naive_bayes import MultinomialNB

# Scale features to [0,1] for MultinomialNB
scaler = MinMaxScaler()  #MultinomialNB expects non-negative features.
X_train_mnb = scaler.fit_transform(X_train)
X_test_mnb = scaler.transform(X_test)

# Train MultinomialNB
mnb = MultinomialNB(alpha=1.0)
mnb.fit(X_train_mnb, y_train)  # Fit first
y_pred_mnb = mnb.predict(X_test_mnb)  # Then predict

# %%
from sklearn.naive_bayes import BernoulliNB
bnb = BernoulliNB(alpha=1.0)
bnb.fit(X_train, y_train)
# Out:
# BernoulliNB()

# %% [markdown]
# ### **GaussianNB Method**

# %%
#--------------------------------------------------
## Model Evaluation for GaussianNB ##
#--------------------------------------------------
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score


ypred_test = gnb.predict(X_test)
mat_clf = confusion_matrix(y_test, ypred_test)
report_clf = classification_report(y_test, ypred_test)

print(mat_clf)
print(report_clf)

auc = roc_auc_score(y_test, ypred_test)
print(auc)
# Out:
# [[8349  192]
#  [  19  118]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      8541
#            1       0.38      0.86      0.53       137
#
#     accuracy                           0.98      8678
#    macro avg       0.69      0.92      0.76      8678
# weighted avg       0.99      0.98      0.98      8678
#
# 0.919417032655709

# %%
#train data
ypred_train =gnb.predict(X_train)
mat_clf = confusion_matrix(y_train, ypred_train)
report_clf = classification_report(y_train, ypred_train)

print(mat_clf)
print(report_clf)

auc = roc_auc_score(y_train, ypred_train)
print(auc)
# Out:
# [[12499   297]
#  [   36   183]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     12796
#            1       0.38      0.84      0.52       219
#
#     accuracy                           0.97     13015
#    macro avg       0.69      0.91      0.76     13015
# weighted avg       0.99      0.97      0.98     13015
#
# 0.9062030300564816

# %% [markdown]
# ### **MultinomialNB Method**

# %%
#Use multinominalNB to predict on the test set #
ypred_test = mnb.predict(X_test)
mat_clf = confusion_matrix(y_test, ypred_test)
report_clf = classification_report(y_test, ypred_test)

print(mat_clf)
print(report_clf)

auc = roc_auc_score(y_test, ypred_test)
print(auc)
# Out:
# [[2226 6315]
#  [  11  126]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.26      0.41      8541
#            1       0.02      0.92      0.04       137
#
#     accuracy                           0.27      8678
#    macro avg       0.51      0.59      0.23      8678
# weighted avg       0.98      0.27      0.41      8678
#
# 0.5901666243632047

# %%
#train data
ypred_train =mnb.predict(X_train)
mat_clf = confusion_matrix(y_train, ypred_train)
report_clf = classification_report(y_train, ypred_train)

print(mat_clf)
print(report_clf)

auc = roc_auc_score(y_train, ypred_train)
print(auc)
# Out:
# [[3180 9616]
#  [  10  209]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.25      0.40     12796
#            1       0.02      0.95      0.04       219
#
#     accuracy                           0.26     13015
#    macro avg       0.51      0.60      0.22     13015
# weighted avg       0.98      0.26      0.39     13015
#
# 0.6014265302655939

# %% [markdown]
# ### **BernoulliNB Method**

# %%
#Use BernoulliNB to predict on the test set #
ypred_test = bnb.predict(X_test)
mat_clf = confusion_matrix(y_test, ypred_test)
report_clf = classification_report(y_test, ypred_test)

print(mat_clf)
print(report_clf)

auc = roc_auc_score(y_test, ypred_test)
print(auc)
# Out:
# [[8533    8]
#  [  33  104]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      8541
#            1       0.93      0.76      0.84       137
#
#     accuracy                           1.00      8678
#    macro avg       0.96      0.88      0.92      8678
# weighted avg       1.00      1.00      1.00      8678
#
# 0.8790937145601679

# %%
#train data
ypred_train =bnb.predict(X_train)
mat_clf = confusion_matrix(y_train, ypred_train)
report_clf = classification_report(y_train, ypred_train)

print(mat_clf)
print(report_clf)

auc = roc_auc_score(y_train, ypred_train)
print(auc)
# Out:
# [[12788     8]
#  [   55   164]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     12796
#            1       0.95      0.75      0.84       219
#
#     accuracy                           1.00     13015
#    macro avg       0.97      0.87      0.92     13015
# weighted avg       1.00      1.00      0.99     13015
#
# 0.8741166260575152
